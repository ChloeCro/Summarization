# %% [markdown]
# # Dataset Analysis

# %%
import pandas as pd

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('C:/Users/Chloe/Documents/MaastrichtLaw&Tech/Summarization/data/data_by_year/2022_rs_data.csv')
df = df.dropna(subset=['procesverloop', 'overwegingen', 'beslissing'])

# %%
df
# Out:
#                           ecli        date  \
# 0           ECLI:NL:CBB:2022:1  2022-01-11
# 3         ECLI:NL:CBB:2022:101  2022-03-08
# 4         ECLI:NL:CBB:2022:102  2022-03-08
# 6         ECLI:NL:CBB:2022:104  2022-03-08
# 8         ECLI:NL:CBB:2022:106  2022-03-08
# ...                        ...         ...
# 123864  ECLI:NL:RBZWB:2022:957  2022-02-25
# 123867   ECLI:NL:RBZWB:2022:96  2022-01-07
# 123876  ECLI:NL:RBZWB:2022:968  2022-02-25
# 123878   ECLI:NL:RBZWB:2022:97  2022-01-07
# 123900   ECLI:NL:RBZWB:2022:99  2022-01-07
#
#                                          inhoudsindicatie  \
# 0       \n\nArtikel 2:3, eerste lid, van de Algemene w...
# 3       \nWarenwet, hoger beroep, Verordening 853/2004...
# 4       \nRegeling garanties van oorsprong en certific...
# 6       \nIntrekking SDE-subsidie zonnepanelen. Artike...
# 8       \nWet ter voorkoming van witwassen en financie...
# ...                                                   ...
# ...
